# %% [markdown]
# # Main Project Notebook: ClinicalNetDynamics (CND)

# %% [markdown]
# # Environment Setup

# %% [markdown]
# ## IMPORTS & PATHS

# %%
import os
import subprocess

# %%
bashCommand = "conda create -n ds_notebook python numpy scipy pandas matplotlib ipython jupyter r-irkernel r-ggplot2 r-tidyverse"
os.system(bashCommand)
# Out:
# ...
# Solving environment: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 22.11.1
#
# Please update conda by running
#
#     $ conda update -n base conda
# ## Package Plan ##
#
#   environment location: /gpfs/milgram/project/holmes/cvc23/conda_envs/ds_notebook
#
#   added / updated specs:
#     - ipython
#     - jupyter
#     - matplotlib
#     - numpy
#     - pandas
#     - python
#     - r-ggplot2
#     - r-irkernel
#     - r-tidyverse
#     - scipy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bwidget-1.9.14             |       ha770c72_1         120 KB  conda-forge
#     jupyter_events-0.6.3       |     pyhd8ed1ab_0          75 KB  conda-forge
#     pandas-1.5.3               |  py311h2872171_0        13.7 MB  conda-forge
#     ------------------------------------------------------------
# ...

# %%
import numpy as np

# %% [markdown]
# # Load Data

# %% [markdown]
# # Data Management

# %% [markdown]
# # Data Processing

# %% [markdown]
# # Functional Connectivity

# %% [markdown]
# # SCRATCH

# %%
import os
bashCommand = "module spider SciPy-bundle/2021.02-foss-2020b"
os.system(bashCommand)

# %%
import os
bashCommand = "module load SciPy-bundle/2021.02-foss-2020b"
os.system(bashCommand)

# %%
import subprocess
#bashCommand = "module load Python/3.8.6-GCCcore-10.2.0 BLAST+/2.11.0-GCCcore-10.2.0"
bashCommand = "module avail"
process = subprocess.Popen(bashCommand.split(), stdout=subprocess.PIPE)
output, error = process.communicate()
